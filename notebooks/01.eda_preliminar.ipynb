# %%
#Trataiento de datos
import pandas as pd
pd.set_option('display.max_columns',None)  # Lim columnas
#-------------------

# %%
df = pd.read_csv ('../data/data_raw.csv')

# %%
'''
#SRC para EDA Preliminar, recopilación codigo en una función.
def eda_preliminar(df):
    display(df.sample(5))  #Muestreo aleatorio
    print('--------------------------')
    print('DIMENSIONES DEL DATASET')
    print(f'El conjunto de datos tiene {df.shape[0]} filas y {df.shape[1]} columnas.')
    print('--------------------------')
    print('INFO')
    display(df.info())  #Info del df
    print('--------------------------')
    print('VALORES NULOS')
    display(df.isnull().mean()*100)  # % de nulos
    print('--------------------------')
    print('DUPLICADOS')
    print(f'Hay un total de {df.duplicated().sum()} duplicados') #Duplicados
    print('FRECUENCIAS DE CATEGÓRICAS')
    for col in df.select_dtypes(include='object').columns: 
        print(col.upper())
        print(df[col].value_counts())
        print('--------------------------')
'''

# %%
'''
eda_preliminar(df) #Llamada a la función
'''
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 1425     1426     B  2022-01-27           0           SPORTS      P1382
# 1766     1767     B  2022-03-18           0      ELECTRONICS      P1789
# 1424     1425     B  2022-01-05           1             TOYS      P1356
# 126       127     B  2022-01-23           0           SPORTS      P1727
# 1211     1212     A  2022-02-28           0            BOOKS      P1210
#
#        Product Name  Quantity   Price Discount Total Value Payment Method  \
# 1425  Running Shoes         0   56,07     0,19         0,0            NaN
# 1766     Headphones         0  771,26      0,1         0,0            NaN
# 1424         Puzzle         2   19,01     0,28       27,37  Bank Transfer
# 126   Running Shoes         0  145,79     0,07         0,0            NaN
# 1211      Biography         0   46,96     0,11         0,0            NaN
#
#      Shipping Method   Region  Customer Age Customer Gender   Device  \
# ...

# %%
df.sample(5)
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 294       295     A  2022-01-03           0         FASHHION      P1584
# 267       268     B  2022-01-09           1            BOOKS      P1553
# 439       440     A  2022-03-29           0         FASHHION      P1768
# 307       308     A  2022-01-14           0         FASHHION      P1715
# 1150     1151     B  2022-01-08           1      ELECTRONICS      P1179
#
#          Product Name  Quantity   Price Discount Total Value Payment Method  \
# 294          Sneakers         0    84,4     0,13         0,0            NaN
# 267   Science Fiction         5   10,63     0,21       41,99    Credit Card
# 439           T-shirt         0  177,83     0,19         0,0            NaN
# 307             Dress         0   85,64     0,07         0,0            NaN
# 1150           Camera         4   302,1     0,22      942,55  Bank Transfer
#
#      Shipping Method Region  Customer Age Customer Gender   Device  \
# ...

# %%
print(f'El conjunto de datos tiene {df.shape[0]} filas y {df.shape[1]} columnas.')
# Out:
# El conjunto de datos tiene 2000 filas y 21 columnas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User Id           2000 non-null   int64
#  1   Group             2000 non-null   object
#  2   Visit Date        2000 non-null   object
#  3   Conversion        2000 non-null   int64
#  4   Product Category  2000 non-null   object
#  5   Product Id        2000 non-null   object
#  6   Product Name      2000 non-null   object
#  7   Quantity          2000 non-null   int64
#  8   Price             1960 non-null   object
#  9   Discount          1960 non-null   object
#  10  Total Value       2000 non-null   object
#  11  Payment Method    247 non-null    object
#  12  Shipping Method   247 non-null    object
#  13  Region            2000 non-null   object
#  14  Customer Age      1960 non-null   float64
#  15  Customer Gender   2000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# User Id                0
# Group                  0
# Visit Date             0
# Conversion             0
# Product Category       0
# Product Id             0
# Product Name           0
# Quantity               0
# Price                 40
# Discount              40
# Total Value            0
# Payment Method      1753
# Shipping Method     1753
# Region                 0
# Customer Age          40
# Customer Gender        0
# Device                 0
# Session Duration       0
# Coupon Used         1753
# Browser                0
# Referral Source        0
# dtype: int64

# %%
#df.isnull().sum()/df.shape[0]*100 #Busco % de nulos
df.isnull().mean()*100  # Otra forma
# Out:
# User Id              0.00
# Group                0.00
# Visit Date           0.00
# Conversion           0.00
# Product Category     0.00
# Product Id           0.00
# Product Name         0.00
# Quantity             0.00
# Price                2.00
# Discount             2.00
# Total Value          0.00
# Payment Method      87.65
# Shipping Method     87.65
# Region               0.00
# Customer Age         2.00
# Customer Gender      0.00
# Device               0.00
# Session Duration     0.00
# Coupon Used         87.65
# Browser              0.00
# Referral Source      0.00
# dtype: float64

# %%
df.duplicated().sum() #Busco duplicados
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User Id', 'Group', 'Visit Date', 'Conversion', 'Product Category',
#        'Product Id', 'Product Name', 'Quantity', 'Price', 'Discount',
#        'Total Value', 'Payment Method', 'Shipping Method', 'Region',
#        'Customer Age', 'Customer Gender', 'Device', 'Session Duration',
#        'Coupon Used', 'Browser', 'Referral Source'],
#       dtype='object')

# %%
#df.select_dtypes(include='object').columns #Busco columnas categóricas
for col in df.select_dtypes(include='object').columns: #Itero por las categóricas y muestra la cantidad de categorías y su frecuencia.
    #print(f'Columna {col} tiene {df[col].nunique()} categorías')
    print(col.upper())
    print(df[col].value_counts())
    print('--------------------------')
# Out:
# GROUP
# Group
# B    1013
# A     987
# Name: count, dtype: int64
# --------------------------
# VISIT DATE
# Visit Date
# 2022-01-28    35
# 2022-02-16    34
# 2022-02-28    32
# 2022-01-19    31
# 2022-01-21    31
#               ..
# 2022-01-18    15
# 2022-03-21    14
# 2022-03-30    14
# 2022-02-21    12
# 2022-01-31    10
# Name: count, Length: 90, dtype: int64
# --------------------------
# PRODUCT CATEGORY
# Product Category
# FASHHION       321
# BOOKS          291
# HOME           287
# SPORTS         282
# TOYS           276
# ELECTRONICS    275
# BEAUTY         268
# Name: count, dtype: int64
# --------------------------
# PRODUCT ID
# Product Id
# P1416    8
# P1782    8
# P1600    7
# P1252    7
# P1798    7
#         ..
# P1641    1
# P1932    1
# P1528    1
# P1732    1
# P1744    1
# Name: count, Length: 867, dtype: int64
# --------------------------
# PRODUCT NAME
# Product Name
# Science Fiction    85
# Smartphone         84
# Jeans              84
# ...
