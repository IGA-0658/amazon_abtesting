# %%
#Trataiento de datos
import pandas as pd
pd.set_option('display.max_columns',None)  # Lim columnas
#-------------------

#Exportacion de archivos SRC
import sys
sys.path.append('../')
#-------------------

#Funciones personalizadas
from src import sp_eda as se
#--

# %%
df = pd.read_csv ('../data/data_raw.csv')

# %%
se.eda_preliminar(df) #Llamo a la función creada en src
# Out:
#       User Id Group  Visit Date  Conversion Product Category Product Id  \
# 574       575     B  2022-03-15           0             TOYS      P1325
# 1240     1241     B  2022-01-15           0           BEAUTY      P1098
# 62         63     B  2022-01-24           1            BOOKS      P1900
# 1600     1601     A  2022-02-17           0      ELECTRONICS      P1204
# 1294     1295     B  2022-03-28           0            BOOKS      P1784
#
#          Product Name  Quantity   Price Discount Total Value Payment Method  \
# 574              Doll         0    73,6     0,14         0,0            NaN
# 1240          Mascara         0   35,19      0,2         0,0            NaN
# 62    Science Fiction         2   36,63     0,24       55,68  Bank Transfer
# 1600       Headphones         0  246,06     0,08         0,0            NaN
# 1294  Science Fiction         0   20,35     0,12         0,0            NaN
#
#      Shipping Method Region  Customer Age Customer Gender   Device  \
# ...
